# %% [markdown]
# # PHYS 331 - Numerical Techniques for the Sciences I
# ## Homework 1: Python Introduction
#
# ### Problem 1 - Plotting in Python using Matplotlib (8 points)
#
# Name: *Greg Tetner*
#
# Onyen: *tetner*
#
# Cell for *Problem 1(a)* is below.

# %%
import numpy as np
import matplotlib.pyplot as plt

def myfunc(xInput):

    yValues = np.tanh(xInput) + 2.0*np.tanh(xInput)
    
    return(yValues)

def main_a():
    # Defining limits and mesh spacing
    x1 = -5.0
    x2 = 5.0
    dx = 0.1
    
    # Defining x axis and y values
    xAxis = np.arange(x1,x2,dx)
    yValues = np.tanh(xAxis)
    
    
    # generating plot
    plt.xlabel("X - axis")
    plt.ylabel("Y - axis")
    plt.plot(xAxis, yValues)
    plt.show()
    
    # ??? A solution is required here. ???
           
main_a()

# %% [markdown]
# ---
# Cell for *Problem 1(b)* and *1(c)* is below.

# %%
import numpy as np
import matplotlib.pyplot as plt

def plotfunc(a):
    x1 = -5.0
    x2 = 5.0
    dx = 0.1
    
    xAxis = np.arange(x1, x2, dx)
    yValues = np.tanh(a * xAxis)
    
    plt.plot(xAxis, yValues, label=f'a = {a}')  # Adding label to the plot

def main_bc():
    plotfunc(0.5)
    plotfunc(1.3)
    plotfunc(2.2)
    
    plt.xlabel("X - axis")
    plt.ylabel("Y - axis")
    plt.legend()  # Adding legend to the plot
    plt.show()
    
    

main_bc()
